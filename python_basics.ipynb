# %% [markdown]
# <a href="https://colab.research.google.com/github/miruthabashini/ml_project_skasc/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## python basics

# %% [markdown]
# ## tuple

# %%
tup=(12,34,66,54,34)
tup
# Out:
# (12, 34, 66, 54, 34)

# %%
print(set(tup))
# Out:
# {34, 12, 66, 54}

# %%
print(list(tup))
# Out:
# [12, 34, 66, 54, 34]

# %%
print(tup[1]) #accessing tuple
# Out:
# 34

# %%
tup=(list(tup))

# %%
tup[0]=79
tup
# Out:
# [79, 34, 66, 54, 34]

# %%
print(tup*4)
# Out:
# [79, 34, 66, 54, 34, 79, 34, 66, 54, 34, 79, 34, 66, 54, 34, 79, 34, 66, 54, 34]

# %%
dic={

    "name":["hashini","dhanu"],
    "Age":[33,27],
    "Gender":["F","F"]
}

# %%
print(dic)
# Out:
# {'name': ['hashini', 'dhanu'], 'Age': [33, 27], 'Gender': ['F', 'F']}

# %%
dic.keys()
# Out:
# dict_keys(['name', 'Age', 'Gender'])

# %%
dic.values()
# Out:
# dict_values([['hashini', 'dhanu'], [33, 27], ['F', 'F']])

# %%
dic.items()
# Out:
# dict_items([('name', ['hashini', 'dhanu']), ('Age', [33, 27]), ('Gender', ['F', 'F'])])

# %%
for key in dic.keys():
  print(key)
# Out:
# name
# Age
# Gender

# %%
for val in dic.values():
  print(val)
# Out:
# ['hashini', 'dhanu']
# [33, 27]
# ['F', 'F']

# %%
for h,d in dic.items():
  print(h,"-->",d)
# Out:
# name --> ['hashini', 'dhanu']
# Age --> [33, 27]
# Gender --> ['F', 'F']

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
lis=[12,34,22,66,76]
arr=np.array(lis)
print(arr)
# Out:
# [12 34 22 66 76]

# %%
print(arr.ndim)
# Out:
# 1

# %%
a=0
b=[1,2,3,4]
c=[[1,2,3],[4,5,6],[7,8,9]]
print(np.array(c).ndim)
# Out:
# 2

# %%
x=[[[14,25,37],[43,54,62],[70,85,93],[20,50,0]]]
print(np.array(x).ndim)
# Out:
# 3

# %%
print(c[1][2])
# Out:
# 6

# %%
print(c[1:])
# Out:
# [[4, 5, 6], [7, 8, 9]]

# %%
list=[2,4,6,8]
arr=np.array(list)
print(arr.reshape(2,2))
# Out:
# [[2 4]
#  [6 8]]

# %%
list=[20,30,40,50,60,70,80,90]
arr=np.array(list)
print(arr.reshape(4,2))
# Out:
# [[20 30]
#  [40 50]
#  [60 70]
#  [80 90]]

# %%
z=np.ones((3,3))
print(z)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
z=np.full((4,4),16)

# %%
z
# Out:
# array([[16, 16, 16, 16],
#        [16, 16, 16, 16],
#        [16, 16, 16, 16],
#        [16, 16, 16, 16]])

# %%
num=[12,45,67,8,90,64]
print("sum",np.sum(num))
print("mean",np.mean(num))
print("max",np.max(num))
print("min",np.min(num))
print("std",np.std(num))
print("var",np.var(num))
print(np.argmax)

# %%
arr=[[1,2,3],[4,5,6]]
arr==np.array(arr)
print(np.sum(arr,axis=0))
# Out:
# [5 7 9]

# %%
arr=[[2,4,6],[8,9,10]]
arr=np.array(arr)
print(np.transpose(arr))
# Out:
# [[ 2  8]
#  [ 4  9]
#  [ 6 10]]

# %%
list=[5,6,7,8,4]
print(np.unique(list))
# Out:
# [4 5 6 7 8]

# %%
print(np.flip(list))
# Out:
# [4 8 7 6 5]

# %% [markdown]
# ## Pandas

# %%
import pandas as pd
from google.colab import files

# %%
up=files.upload()
# Out:
#      <input type="file" id="files-31f8fb93-f574-4dee-8445-2f69c353f7db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31f8fb93-f574-4dee-8445-2f69c353f7db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv(r'pandas.csv')

# %%
data
# Out:
#     S.NO    NAME   AGE  GENDER     CITY
# 0      1     RAJ  34.0    MALE  CHENNAI
# 1      2    MANI   NaN    MALE    DELHI
# 2      3   KUMAR  55.0    MALE      NaN
# 3      4   RAHUL  23.0    MALE  MADURAI
# 4      5   GOKUL  24.0    MALE      NaN
# 5      6   SHIVA  23.0    MALE   MUMBAI
# 6      7   MALAR  67.0  FEMALE      NaN
# 7      8    BALA  55.0    MALE    THENI
# 8      9  SWATHI  45.0  FEMALE   TRICHY
# 9     10    JOHN   NaN    MALE  CHENNAI
# 10     8    BALA  22.0    MALE    THENI
# 11    10    JOHN  25.0    MALE  CHENNAI
# 12     4   RAHUL  23.0    MALE  MADURAI

# %%
df=pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S.NO    13 non-null     int64
#  1   NAME    13 non-null     object
#  2   AGE     11 non-null     float64
#  3   GENDER  13 non-null     object
#  4   CITY    10 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 652.0+ bytes

# %%
df.describe()
# Out:
#             S.NO        AGE
# count  13.000000  11.000000
# mean    5.923077  36.000000
# std     3.012793  16.540859
# min     1.000000  22.000000
# 25%     4.000000  23.000000
# 50%     6.000000  25.000000
# 75%     8.000000  50.000000
# max    10.000000  67.000000

# %%
df.head()
# Out:
#    S.NO   NAME   AGE GENDER     CITY
# 0     1    RAJ  34.0   MALE  CHENNAI
# 1     2   MANI   NaN   MALE    DELHI
# 2     3  KUMAR  55.0   MALE      NaN
# 3     4  RAHUL  23.0   MALE  MADURAI
# 4     5  GOKUL  24.0   MALE      NaN

# %%
df.head(3)
# Out:
#    S.NO   NAME   AGE GENDER     CITY
# 0     1    RAJ  34.0   MALE  CHENNAI
# 1     2   MANI   NaN   MALE    DELHI
# 2     3  KUMAR  55.0   MALE      NaN

# %%
df.tail()
# Out:
#     S.NO    NAME   AGE  GENDER     CITY
# 8      9  SWATHI  45.0  FEMALE   TRICHY
# 9     10    JOHN   NaN    MALE  CHENNAI
# 10     8    BALA  22.0    MALE    THENI
# 11    10    JOHN  25.0    MALE  CHENNAI
# 12     4   RAHUL  23.0    MALE  MADURAI

# %%
df.tail(4)
# Out:
#     S.NO   NAME   AGE GENDER     CITY
# 9     10   JOHN   NaN   MALE  CHENNAI
# 10     8   BALA  22.0   MALE    THENI
# 11    10   JOHN  25.0   MALE  CHENNAI
# 12     4  RAHUL  23.0   MALE  MADURAI

# %%
df.isnull().sum()
# Out:
# S.NO      0
# NAME      0
# AGE       2
# GENDER    0
# CITY      3
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# ## handling duplicates

# %%
df.dropna()   #helps to erace blank space's entire row
# Out:
#     S.NO    NAME   AGE  GENDER     CITY
# 0      1     RAJ  34.0    MALE  CHENNAI
# 3      4   RAHUL  23.0    MALE  MADURAI
# 5      6   SHIVA  23.0    MALE   MUMBAI
# 7      8    BALA  55.0    MALE    THENI
# 8      9  SWATHI  45.0  FEMALE   TRICHY
# 10     8    BALA  22.0    MALE    THENI
# 11    10    JOHN  25.0    MALE  CHENNAI
# 12     4   RAHUL  23.0    MALE  MADURAI

# %%
df.fillna("no data") #instead of NaN it will appear no data
# Out:
#     S.NO    NAME      AGE  GENDER     CITY
# 0      1     RAJ     34.0    MALE  CHENNAI
# 1      2    MANI  no data    MALE    DELHI
# 2      3   KUMAR     55.0    MALE  no data
# 3      4   RAHUL     23.0    MALE  MADURAI
# 4      5   GOKUL     24.0    MALE  no data
# 5      6   SHIVA     23.0    MALE   MUMBAI
# 6      7   MALAR     67.0  FEMALE  no data
# 7      8    BALA     55.0    MALE    THENI
# 8      9  SWATHI     45.0  FEMALE   TRICHY
# 9     10    JOHN  no data    MALE  CHENNAI
# 10     8    BALA     22.0    MALE    THENI
# 11    10    JOHN     25.0    MALE  CHENNAI
# 12     4   RAHUL     23.0    MALE  MADURAI

# %%
avg=df['AGE'].mean()

# %%
avg
# Out:
# np.float64(36.0)

# %%
df
# Out:
#     S.NO    NAME   AGE  GENDER     CITY
# 0      1     RAJ  34.0    MALE  CHENNAI
# 1      2    MANI   NaN    MALE    DELHI
# 2      3   KUMAR  55.0    MALE      NaN
# 3      4   RAHUL  23.0    MALE  MADURAI
# 4      5   GOKUL  24.0    MALE      NaN
# 5      6   SHIVA  23.0    MALE   MUMBAI
# 6      7   MALAR  67.0  FEMALE      NaN
# 7      8    BALA  55.0    MALE    THENI
# 8      9  SWATHI  45.0  FEMALE   TRICHY
# 9     10    JOHN   NaN    MALE  CHENNAI
# 10     8    BALA  22.0    MALE    THENI
# 11    10    JOHN  25.0    MALE  CHENNAI
# 12     4   RAHUL  23.0    MALE  MADURAI

# %%
df['AGE'].fillna(avg)
# Out:
# 0     34.0
# 1     36.0
# 2     55.0
# 3     23.0
# 4     24.0
# 5     23.0
# 6     67.0
# 7     55.0
# 8     45.0
# 9     36.0
# 10    22.0
# 11    25.0
# 12    23.0
# Name: AGE, dtype: float64

# %%
df['AGE'].fillna(avg,inplace=True)
# Out:
# /tmp/ipython-input-312020896.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AGE'].fillna(avg,inplace=True)

# %%
df
# Out:
#     S.NO    NAME   AGE  GENDER     CITY
# 0      1     RAJ  34.0    MALE  CHENNAI
# 1      2    MANI  36.0    MALE    DELHI
# 2      3   KUMAR  55.0    MALE      NaN
# 3      4   RAHUL  23.0    MALE  MADURAI
# 4      5   GOKUL  24.0    MALE      NaN
# 5      6   SHIVA  23.0    MALE   MUMBAI
# 6      7   MALAR  67.0  FEMALE      NaN
# 7      8    BALA  55.0    MALE    THENI
# 8      9  SWATHI  45.0  FEMALE   TRICHY
# 9     10    JOHN  36.0    MALE  CHENNAI
# 10     8    BALA  22.0    MALE    THENI
# 11    10    JOHN  25.0    MALE  CHENNAI
# 12     4   RAHUL  23.0    MALE  MADURAI

# %%
df['GENDER']=df['GENDER'].replace("Male","M")

# %%
df['GENDER']=df['GENDER'].replace("female","F")

# %% [markdown]
# ## group by and pivot table

# %%
group=df.groupby('GENDER')['AGE'].mean()

# %%
pivot=pd.pivot_table(df,
                     values='AGE',
                     index='CITY',
                     columns='gender',
                     aggfunc='sum'.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3078823262.py in <cell line: 0>()
# ----> 1 pivot=pd.pivot_table(df,
#       2                      values='AGE',
#       3                      index='CITY',
#       4                      columns='GENDER',
#       5                      aggfunc='sum')
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## matplot_visualization

# %%
import matplotlib.pyplot as plt

# %%
df['CITY']=df['CITY'].fillna('unknown')
plt.bar(df['CITY'],df['AGE'],color='red')
Plt.xlabel("city")
plt.ylabel("age")
plt.xticks(rotation=45)
plt.title("Bar Graph")
plt.show()

# %% [markdown]
# ## eda-global super store dataset

# %%
from google.colab import files
up=files.upload()
# Out:
#      <input type="file" id="files-7fd64b74-c2bd-4b8a-85dc-addddf60888b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fd64b74-c2bd-4b8a-85dc-addddf60888b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r'Global_Superstorel.xlsx')

# %%
df=pd.dDataFrame(data)

# %%
data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9998 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9998.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528  55185.270254    246.490581
# min              2011-01-03 00:00:00   1040.000000      0.444000
# 25%              2012-06-23 00:00:00  23223.000000     30.758625
# 50%              2013-07-12 00:00:00  56301.000000     85.053000
# 75%              2014-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Postal Code       0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
plt.bar(df['sub_category'],df['sales'])
plt.title("sub_caty vs sales")
plt.xlabel("sub_cat")
plt.ylabel("sales")
plt.xticks(rotation=45)
plt.show()

# %%
group1=df.groupby('Category')['Sales'].sum()

# %%
group1
# Out:
# Category
# Furniture          4.110874e+06
# Office Supplies    3.787070e+06
# Technology         4.744557e+06
# Name: Sales, dtype: float64

# %%
plt.pie(group1,labels=['Furniture','Office Supplies','Technology'])
plt.legend()
plt.show()
